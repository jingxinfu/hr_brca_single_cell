# %%
REPO = '../'
RESULT_TABLE = f'{REPO}/data/table'
RESULT_OBJ = f'{REPO}/data/object'
FIGURE_FOLDER= f'{REPO}/data/figure'
SETTING_FOLDER = f'{REPO}/data/setting'
EXTERNAL_DATA=f'{REPO}/data/external'
# load Terra API for get data table from Terra
import sys
sys.path.append(REPO)
from settings import COLOR_PAlETTE
from utils.visual import *

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scPipe as sp
import scanpy as sc
import seaborn as sns
import pickle
import warnings
import commentjson
### Additional Colormap
with open(f'{SETTING_FOLDER}/ColorMap.json','r') as f:
    colormap = commentjson.load(f)
COLOR_PAlETTE.update(colormap)
plt.style.use(f'{REPO}/paper.mplstyle')
warnings.filterwarnings("ignore")
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mp_gmt_path = f'{RESULT_TABLE}/MPs/Tumor/MP_Programs.gmt'
anno = pd.read_csv(f'{RESULT_TABLE}/MPs/Tumor/MetaProgram_Annotation.csv')
with open(f'{RESULT_TABLE}/MPs/Tumor/MP_anno_map.pickle', "rb") as input_file:
    MP_anno_map= pickle.load(input_file)

with open(f'{RESULT_TABLE}/MPs/Tumor/MP_order_color.pickle', "rb") as input_file:
    MP_order_color = pickle.load(input_file)
    COLOR_PAlETTE['MetaProgram'] = MP_order_color['MP_Colors']
    del MP_order_color
    
MP_Genesets = pd.read_csv(mp_gmt_path,sep='\t',header=None,index_col=0).iloc[:,1:].T

# %%
MP_Genesets.rename(columns=MP_anno_map).to_csv(f'{RESULT_TABLE}/MPs/Tumor/MP_Programs.csv',index=False) # share

# %% [markdown]
# # Representative gene set  selection

# %%
anno['MPs'] = anno.MetaProgram.map(MP_anno_map)
anno['MPs'].value_counts().sort_index()
# Out:
# Apelin                  4
# Cell_Cycle             24
# EMT-I                  12
# EMT-II                  6
# EMT-III                 5
# ER-I                    3
# ER-II                   5
# Interferon/MHCII(I)     7
# Stress                  5
# Name: MPs, dtype: int64

# %%
MP_Visual_Genes = {
    'MP2':["BRCA1","TOP2A","TPX2"],
    'MP3':["VIM","FN1","VCAN"],
    'MP4':['STAT1','TAP1','CXCL10'],
    'MP5':['CCN1','TIPARP','CCNL1'],
    'MP6':['TNFRSF12A','FLNA','PMEPA1'],
    'MP7':['GATA3','FUT8','RHOBTB3'],
    'MP8':['AR','PAPSS2','DHRS2'],
    'MP9':['GNGT1','MAP1B','NEGR1'],
    'MP11':['DST','PAM','XDH']
}

# %%
genes = pd.Series(np.vstack(MP_Visual_Genes.values()).flatten())
genes.index=genes
dt = MP_Genesets.apply(lambda c: genes.map(lambda x: x in c.values),axis=0).astype(int)
dt = dt.sort_values(dt.columns.tolist())

df_rows = pd.DataFrame(MP_Visual_Genes).unstack().reset_index().set_index(0)
colors = { MP_anno_map[k]:v for k,v in COLOR_PAlETTE['MetaProgram'].items() if k in df_rows['level_0'].unique()}
df_rows['MP'] = df_rows['level_0'].map(MP_anno_map)
df_rows = df_rows.sort_values('MP')
col_orders = df_rows['level_0'].unique().tolist()
dt = dt[col_orders].sort_values(col_orders,ascending=False)
df_rows = df_rows.loc[dt.index,:]

row_ha = HeatmapAnnotation(
    Function=anno_simple(df_rows['MP'],legend=False,
                           legend_kws=dict(frameon=False),
                           colors=colors),
     Anno=anno_label(df_rows['MP'],legend=False,
                          colors=colors,merge=True),
    verbose=0,axis=0,plot_legend=True)


plt.figure(figsize=(4, 10),dpi=150)
cm = ClusterMapPlotter(data=dt,
                       right_annotation=row_ha,
                       col_cluster=False,
                       row_cluster=False,
                       show_colnames=True,
                       show_rownames=True,
                       vmax=1,
                       vmin=0,
                       label='Gene In the MP',
                       cmap='Greys',rasterized=True,col_names_side='top')
plt.suptitle('Metaprogram related function')
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 7.5 mm
# Text(0.5, 0.98, 'Metaprogram related function')

# %% [markdown]
# # Cellstate annotation
#
# ## signature score calculation

# %%
obs_path = f'{RESULT_TABLE}/annotation/Epithelial.csv'
adata = sc.read(f'{RESULT_OBJ}/gex_all.h5ad')
obs = pd.read_csv(obs_path,index_col=0)
adata = adata[adata.obs.index.isin(obs.index[obs.Lineage=='Tumor']),:]

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
mp_result = sp.ext.VISION(data=adata,gmt_files=[mp_gmt_path],outdir='.')
# Out:
# Rscript /home/analysis/scPipe/scPipe/Rscripts/VISION.R --gmt_files ..//data/table/MPs/Tumor/MP_Programs.gmt --h5ad /tmp/tmpzwwkxy2j/count.h5ad --output_file /tmp/tmpzwwkxy2j/vision.tsv
# $gmt_files
# [1] "..//data/table/MPs/Tumor/MP_Programs.gmt"
#
# $h5ad
# [1] "/tmp/tmpzwwkxy2j/count.h5ad"
#
# $output_file
# [1] "/tmp/tmpzwwkxy2j/vision.tsv"
# Loading data from ..//data/table/MPs/Tumor/MP_Programs.gmt ...
#
# Using 25905/35002 genes detected in 0.10% of cells for signature analysis.
# See the `sig_gene_threshold` input to change this behavior.
#
# Evaluating signature scores on cells...
#
# 'as(<matrix>, "dgeMatrix")' is deprecated.
# Use 'as(as(as(., "dMatrix"), "generalMatrix"), "unpackedMatrix")' instead.
# See help("Deprecated") and help("Matrix-deprecated").
# Evaluating signature-gene importance...
#
# Warning messages:
# 1: In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 17.0 GiB
# 2: In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 17.0 GiB

# %%
scores_path =f'{RESULT_TABLE}/MPs/Tumor/signature_scores.csv'
mp_result.to_csv(scores_path)

# %%
# get MP sores on all cells 
scores = pd.read_csv(scores_path,index_col=0)
# select the signature scoring method
scores.columns = scores.columns.map(MP_anno_map)
scores
# Out:
#                                                     Interferon/MHCII(I)  \
# CTCTAGCTCCGTGACA-1_CCG1112_16_T4_A1_CCG1112_MO_...             1.050517
# AGCGATTTCTATTGTC-1_CCG1112_16_T4_A1_CCG1112_MO_...             1.022604
# GTGCACGGTATACTGG-1_CCG1112_16_T4_A1_CCG1112_MO_...             1.034953
# TCCACAACACATGCTA-1_CCG1112_16_T4_A1_CCG1112_MO_...             0.821911
# ATGAATGCATCCGTAA-1_CCG1112_16_T4_A1_CCG1112_MO_...             0.466932
# ...                                                                 ...
# CATCGAATCGACAGCC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...            -0.014982
# ACTGCTCTCATTCACT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...             0.155636
# GAACATCGTAAGAGGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...             0.218737
# CATCAAGGTCTGGAGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...            -0.125677
# TGCACCTAGATCCCGC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...            -0.129911
#
#                                                     Cell_Cycle     EMT-I  \
# CTCTAGCTCCGTGACA-1_CCG1112_16_T4_A1_CCG1112_MO_...    0.912731  2.088148
# AGCGATTTCTATTGTC-1_CCG1112_16_T4_A1_CCG1112_MO_...    0.595974  1.468868
# GTGCACGGTATACTGG-1_CCG1112_16_T4_A1_CCG1112_MO_...    0.632573  1.856946
# TCCACAACACATGCTA-1_CCG1112_16_T4_A1_CCG1112_MO_...    1.033779  1.982006
# ATGAATGCATCCGTAA-1_CCG1112_16_T4_A1_CCG1112_MO_...    0.666564  0.443668
# ...                                                        ...       ...
# CATCGAATCGACAGCC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...   -0.142421  0.112456
# ACTGCTCTCATTCACT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...   -0.141162  0.221605
# GAACATCGTAAGAGGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.183736  0.321913
# CATCAAGGTCTGGAGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.022167 -0.125677
# TGCACCTAGATCCCGC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...   -0.129911 -0.129911
#
#                                                       EMT-II      ER-I  \
# CTCTAGCTCCGTGACA-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.945141  0.759949
# AGCGATTTCTATTGTC-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.694230  0.367143
# GTGCACGGTATACTGG-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.879244  0.418232
# TCCACAACACATGCTA-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.246094  1.660039
# ATGAATGCATCCGTAA-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.834911  4.146263
# ...                                                      ...       ...
# CATCGAATCGACAGCC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.147662  0.863770
# ACTGCTCTCATTCACT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.251462  0.907999
# GAACATCGTAAGAGGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.342187  0.451136
# CATCAAGGTCTGGAGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.022167  0.207240
# TGCACCTAGATCCCGC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.695796  0.192704
#
#                                                       Stress     ER-II  \
# CTCTAGCTCCGTGACA-1_CCG1112_16_T4_A1_CCG1112_MO_...  0.998746  0.380491
# AGCGATTTCTATTGTC-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.110749  0.359184
# GTGCACGGTATACTGG-1_CCG1112_16_T4_A1_CCG1112_MO_...  0.630465  0.747757
# TCCACAACACATGCTA-1_CCG1112_16_T4_A1_CCG1112_MO_...  0.587242  0.937801
# ATGAATGCATCCGTAA-1_CCG1112_16_T4_A1_CCG1112_MO_...  0.584310  2.302292
# ...                                                      ...       ...
# CATCGAATCGACAGCC-1_CCG1112_13_T3_A1_SN_5GEX_CCG... -0.014982  1.203867
# ACTGCTCTCATTCACT-1_CCG1112_13_T3_A1_SN_5GEX_CCG... -0.010287  0.937441
# GAACATCGTAAGAGGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.895163  0.397328
# CATCAAGGTCTGGAGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.022167  0.748931
# TGCACCTAGATCCCGC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.013262  0.551590
#
#                                                      EMT-III    Apelin
# CTCTAGCTCCGTGACA-1_CCG1112_16_T4_A1_CCG1112_MO_...  3.569743  0.962208
# AGCGATTTCTATTGTC-1_CCG1112_16_T4_A1_CCG1112_MO_...  4.202474  0.972670
# GTGCACGGTATACTGG-1_CCG1112_16_T4_A1_CCG1112_MO_...  5.583303  1.176489
# TCCACAACACATGCTA-1_CCG1112_16_T4_A1_CCG1112_MO_...  4.156854  1.000669
# ATGAATGCATCCGTAA-1_CCG1112_16_T4_A1_CCG1112_MO_...  0.860328  1.565529
# ...                                                      ...       ...
# CATCGAATCGACAGCC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.586435  0.368079
# ACTGCTCTCATTCACT-1_CCG1112_13_T3_A1_SN_5GEX_CCG... -0.010287  0.322748
# GAACATCGTAAGAGGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  2.088933  0.411389
# CATCAAGGTCTGGAGA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.257963  0.863906
# TGCACCTAGATCCCGC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.299607  0.230008
#
# [65206 rows x 9 columns]

# %% [markdown]
# ## GMM assignment

# %%
from signaturescoring.scoring_methods.gmm_postprocessing import GMMPostprocessor
import anndata
tumor = anndata.AnnData(obs=scores)
# initialize GMMPostprocessor
gmm_post = GMMPostprocessor(
    n_components=scores.shape[1]
)
# fit the GMM model on the 3 columns of the scores
features_name = scores.columns.tolist()
store_name_pred, store_names_proba, _ = gmm_post.fit_and_predict(tumor,features_name )

# assign clusters to signatures
assignments = gmm_post.assign_clusters_to_signatures(tumor,features_name, store_names_proba, plot=False)
scoring_names_gmm = []
for key, val in assignments.items():
    if key =='rest':
        continue
    tumor.obs[key+'_gmm'] = tumor.obs[val].copy()
    scoring_names_gmm.append(key+'_gmm')

# %%
pd.Series(assignments).iloc[:-1].sort_values()
# Out:
# EMT-III                1_GMM_proba
# ER-II                  4_GMM_proba
# EMT-II                 5_GMM_proba
# Stress                 5_GMM_proba
# Cell_Cycle             6_GMM_proba
# ER-I                   7_GMM_proba
# Apelin                 7_GMM_proba
# Interferon/MHCII(I)    8_GMM_proba
# EMT-I                  8_GMM_proba
# dtype: object

# %% [markdown]
# ## Explore the correlation between MPs

# %%
dt =  scores.copy()
order = pd.Series(assignments).iloc[:-1].sort_values().index.tolist()
pvalues = []
for c in dt:
    p = dt.apply(lambda a: scipy.stats.pearsonr(a.values,dt[c].values)[1])
    p.name= c
    pvalues.append(p)
pvalues = pd.concat(pvalues,axis=1)
corr =  dt.corr()

data = corr.unstack().rename('Correlation').to_frame()
data['pvalue'] = pvalues.unstack()
data['Significance'] = 'N.S'
data.loc[data['pvalue']<0.01,'Significance'] = 'p<0.01'

data = data.reset_index()#.drop_duplicates(['pvalue','Correlation'])
# data = data.loc[data.level_0!=data.level_1,:]

plt.figure(figsize=(3, 3),dpi=150)


# col_ha = HeatmapAnnotation(label=anno_label(pd.Series(['Endocytosis','Lipid','Presentation','Interferon','Adhesion','Secretion'])))
cm = DotClustermapPlotter(data=data, x='level_0',y='level_1',value='Correlation',c='Correlation',hue='Significance',
                          s=4,
                          col_split=pd.Series(order,index=order),
                          col_split_order = order,
                          row_split=pd.Series(order,index=order),
                          row_split_order = order,
                          marker={'N.S':'x','p<0.01':'s'},
                          vmax=.7,vmin=-.7,cmap='RdBu_r',
                          ratio=200,
                          row_cluster=False,col_cluster=False,
                          show_rownames=True,show_colnames=True,row_names_side='left')
plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 30.516666666666666 mm

# %%
curr_val= tumor.obs[scoring_names_gmm].idxmax(axis="columns")
cellstate= curr_val.map(lambda x:'Tumor.'+x.replace('_gmm','')).rename('Cellstate').to_frame()
cellstate.to_csv(f'{RESULT_TABLE}/MPs/Tumor/Annotation.csv')

# %% [markdown]
# # MP marker visualization

# %%
obs_path = f'{RESULT_TABLE}/annotation/Epithelial.csv'
adata = sc.read(f'{RESULT_OBJ}/gex_all.h5ad')
sample_meta =  pd.read_excel(f'{RESULT_TABLE}/Supplementary Table 1.xlsx',index_col=0).replace(np.nan,'N/A')
obs = pd.read_csv(obs_path,index_col=0)
adata = adata[adata.obs.index.isin(obs.index[obs.Lineage=='Tumor']),:]
adata.obs['Cellstate']= cellstate['Cellstate']
adata.obs = adata.obs.merge(sample_meta,left_on='Sample',right_on='CCG_ID')
sp.utils.log1pNorm(adata)

# %%
MP_Genesets.columns = MP_Genesets.columns.map(MP_anno_map)
MP_Genesets=MP_Genesets.melt()
MP_Genesets.columns = ['Program','gene']
MP_Genesets = MP_Genesets.drop_duplicates(subset=['gene'],keep=False).set_index('gene')

# %%
palette={}
palette['Program'] = {k.replace('Tumor.',''):v for k,v in COLOR_PAlETTE['Cellstate'].items() if 'Tumor' in k}
for c in ['Patient','Timepoint','Cellstate']:
    palette[c] = COLOR_PAlETTE[c]
aggregate_heatmap(adata=adata,
                  features=MP_Genesets,
                  top_anno_columns=['Cellstate','Timepoint','Patient'],
                  col_split='Cellstate',
                  col_split_gap=1,
                  row_split='Program',
                  row_split_gap=1,
                  palette=palette,
                  figsize=(10,10),
                  vmin=-3,
                  vmax=3,
                  standard_normalization=True,
                  cbar_label='Expression\n(Normalized)',
                  cmap='RdBu_r'
                 )
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 28.22361111111111 mm

# %%
REPO = '../'
RESULT_TABLE = f'{REPO}/data/table'
RESULT_OBJ = f'{REPO}/data/object'
FIGURE_FOLDER= f'{REPO}/data/figure'
SETTING_FOLDER = f'{REPO}/data/setting'
EXTERNAL_DATA=f'{REPO}/data/external'

# load Terra API for get data table from Terra
import sys
import glob
sys.path.append(REPO)
from settings import COLOR_PAlETTE
from utils.visual import *

# load packages and data for the following analysis
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scPipe as sp
import scanpy as sc
import scanpy.external as sce
import seaborn as sns
from statannotations.Annotator import Annotator
import warnings
import commentjson
### Additional Colormap
with open(f'{SETTING_FOLDER}/ColorMap.json','r') as f:
    colormap = commentjson.load(f)
COLOR_PAlETTE.update(colormap)
plt.style.use(f'{REPO}/paper.mplstyle')

warnings.filterwarnings("ignore")
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
obs_path =  f'{RESULT_TABLE}/GEX_OBS_Lineage.csv'
adata = sc.read(f'{RESULT_OBJ}/gex_all.h5ad')
obs = pd.read_csv(obs_path,index_col=0)

adata = adata[adata.obs.index.isin(obs.index[obs.Lineage=='CAF']),:]
print(f'{adata.obs.shape[0]:,} CAF')
sample_meta =  pd.read_excel(f'{RESULT_TABLE}/Supplementary Table 1.xlsx',index_col=0).replace(np.nan,'N/A')
Celltype='CAF'

# %% [markdown]
# # Detect the robust recurrent program robustRPH
#
# - Run the workflow https://app.terra.bio/#workspaces/vanallen-firecloud-nih/HR_BrCa_16-466/workflows/jf_scpipe_rna/GEX_CohortSet_DetectRHP
# - Get the basis and coef pickle files.

# %%
import pickle
with open(f'{RESULT_TABLE}/MPs/{Celltype}/nmf_basis.pickle', "rb") as input_file:
    programs_basis = pickle.load(input_file)

with open(f'{RESULT_TABLE}/MPs/{Celltype}/nmf_coef.pickle', "rb") as input_file:
    programs_coef = pickle.load(input_file)
    
n_programs = programs_basis[list(programs_basis.keys())[2]].shape[1] * len(programs_basis)
f"Generated {n_programs:,} programs"
# Out:
# 'Generated 1,443 programs'

# %%
n_top=50
# if not os.path.isdir(f'{RESULT_TABLE}/MPs/{Celltype}'):
#     os.makedirs(f'{RESULT_TABLE}/MPs/{Celltype}')
# robustRPH = sp.ext.getRobustRHP(programs=programs_basis,
#                          n_top=n_top,
#                          intra_min = 35, inter_min = 10,intra_max = 10
#                         )
# with open(f'{RESULT_TABLE}/MPs/{Celltype}/robustRPH.pickle', 'wb') as handle:
#     pickle.dump(robustRPH, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(f'{RESULT_TABLE}/MPs/{Celltype}/robustRPH.pickle', "rb") as input_file:
    robustRPH = pickle.load(input_file)
f"Out of {n_programs:,} detected programs, {robustRPH.shape[1]} programs are robust."
# Out:
# 'Out of 1,443 detected programs, 256 programs are robust.'

# %% [markdown]
# ## Get a list of genes included in the analysis

# %%
bg_genes = pd.Index([])
for k,v in programs_basis.items():
    bg_genes = v.index.union(bg_genes)

# %% [markdown]
# ## Customized clustering on the RPH
#
# ### Look at how the n of samples in various timepoints and conditions

# %%
sample_stats = pd.crosstab(index=[sample_meta['Treatment_Arm'],sample_meta['Timepoint']],
            columns=sample_meta['BestResponse'])

sample_stats['total'] =sample_stats.sum(axis=1)
sample_stats
# Out:
# BestResponse               favorable response\n(RCB 0-I)  \
# Treatment_Arm Timepoint
# Chemo->Combo  Baseline                                 1
#               Pre-surgery                              0
#               Surgery                                  1
#               W3D1                                     2
#               W7D1                                     3
# ICI->Combo    Baseline                                 2
#               Pre-surgery                              1
#               Surgery                                  0
#               W3D1                                     0
#               W7D1                                     1
#
# BestResponse               unfavorable response\n(RCB II-III)  total
# Treatment_Arm Timepoint
# Chemo->Combo  Baseline                                      3      4
#               Pre-surgery                                   2      2
#               Surgery                                       2      3
#               W3D1                                          3      5
#               W7D1                                          1      4
# ICI->Combo    Baseline                                      6      8
#               Pre-surgery                                   1      2
#               Surgery                                       4      4
#               W3D1                                          4      4
#               W7D1                                          3      4

# %% [markdown]
# ### Perform the clustering
#
# as shown above, in timepoints Baseline, W3D1, W7D1, and AfterSurg, we have at least `2` samples per timepoints. Thus, we aimed to find metaprograms that at least shared among three samples and set the `Min_group_size` parameter to be `3`.

# %%
import palettable
Cluster_Map,MP_Genesets,Programs_Order,MP_colors = sp.ext.clusterRobustRPH(
    robustRPH=robustRPH,
    programs_basis=programs_basis,
    Min_group_size=3,
    palette=palettable.tableau.Tableau_20.hex_colors + palettable.tableau.TrafficLight_9.hex_colors
)
# Out:
# [Processing]Cluster MP1 has 33 RPH programs.
# [Processing]Cluster MP2 has 47 RPH programs.
# [Processing]Cluster MP3 has 45 RPH programs.
# [Processing]Cluster MP4 has 16 RPH programs.
# [Processing]Cluster MP5 has 15 RPH programs.
# [Processing]Cluster MP6 has 12 RPH programs.
# [Processing]Cluster MP7 has 8 RPH programs.
# [Processing]Cluster MP8 has 12 RPH programs.
# [Processing]Cluster MP9 has 8 RPH programs.
# [Processing]Cluster MP10 has 8 RPH programs.
# [Done] Generated 10 MP clusters which covered 80% robust RPH programs.

# %% [markdown]
# ### Look at MPs related to low data quality

# %%
display(pd.concat([
    MP_Genesets.apply(lambda c:c.str.startswith('MT-').sum(),axis=0).rename('Mitochondrial'),
    MP_Genesets.apply(lambda c:c.str.contains('^RP[LS]').sum(),axis=0).rename('Ribosomal')
],axis=1).sort_values(['Mitochondrial','Ribosomal'],ascending=False))

low_quality_mps = ['MP1']
# Out:
#       Mitochondrial  Ribosomal
# MP1              10         29
# MP2               0          0
# MP3               0          0
# MP4               0          0
# MP5               0          0
# MP6               0          0
# MP7               0          0
# MP8               0          0
# MP9               0          0
# MP10              0          0

# %% [markdown]
# ### Merge sample metadata into the clustering result

# %%
anno = Cluster_Map.rename('MetaProgram').to_frame()
anno['Sample'] = anno.index.map(lambda x: x.split('.')[0])
anno = anno.reset_index().merge(sample_meta,left_on='Sample',right_on='CCG_ID',how='left').set_index('index')

# %% [markdown]
# ### explore the patient specific programs

# %%
pt_specific = anno.groupby(['MetaProgram'])['Patient'].nunique().sort_values()
pt_specific = pt_specific[pt_specific ==1].index.tolist()

# %%
anno['MetaProgram'].value_counts()[pt_specific]
# Out:
# Series([], Name: MetaProgram, dtype: int64)

# %%
anno.loc[anno['MetaProgram'].isin(pt_specific),:]
# Out:
# Empty DataFrame
# Columns: [MetaProgram, Sample, CCG_ID, BluePrint, Batch, AC_Treatment, Tech, WES_Profile, BulkRNA_Profile, PAM50, BestResponse, Timepoint, stage, Patient, Treatment_Arm]
# Index: []

# %% [markdown]
# ###  Calculate the complexity correaltion

# %%
nmf_corr_complexity = []
for k,v in programs_coef.items():
    # only keep cells iwth genes > 1,000
    tmp = v.corrwith(adata.obs.loc[adata.obs.index.isin(v.index),'n_genes_by_counts'])
    nmf_corr_complexity.append(tmp)
del tmp
nmf_corr_complexity=pd.concat(nmf_corr_complexity,axis=0)
dt = pd.concat([nmf_corr_complexity.abs()>.4,Cluster_Map],axis=1,join='inner').groupby(1)[0].mean()
high_complexity = dt[dt>.5].index.tolist()
high_complexity
# Out:
# []

# %% [markdown]
# ### Remove patient specific, high complexity, and unknown program

# %%
anno = anno.loc[~anno['MetaProgram'].isin(pt_specific+['MP_Unknown']+low_quality_mps+high_complexity),:]
New_Programs_Order = [ x for x in Programs_Order if x in anno.index]
New_MP_Genesets = MP_Genesets[anno['MetaProgram'].unique().tolist()]
f"Generated {anno['MetaProgram'].nunique()} MP clusters which covered {(anno.shape[0]/robustRPH.shape[1]):.0%} robust RPH programs."
# Out:
# 'Generated 9 MP clusters which covered 67% robust RPH programs.'

# %% [markdown]
# ## Visualize the program similarity

# %% [markdown]
# ### Visualize the similarity

# %%
def jaccard_index(c1,c2):
    c1 = set(c1)
    c2 = set(c2)
    overlap =  c1.intersection(c2)
    union = c1.union(c2)
    value = len(overlap)/len(union)
    return value

## Jaccard index    
sm = robustRPH.apply(
        lambda c1:
            robustRPH.apply(
            lambda c2: jaccard_index(c1,c2) * 100
            ,axis=0)
        ,axis=0)

# %%
from PyComplexHeatmap import \
ClusterMapPlotter,HeatmapAnnotation,anno_simple,anno_label,DotClustermapPlotter,anno_scatterplot
## Get the order the program
anno['Cell_complexity_cor'] = nmf_corr_complexity
order = New_Programs_Order

## column annotation
n_mp = Cluster_Map.nunique()
COLOR_PAlETTE['MetaProgram'] = MP_colors
col_dict={}
for col in ['Timepoint','Patient','MetaProgram']:#'Treatment_Arm',
    colors = { k:v for k,v in COLOR_PAlETTE[col].items() if k in anno[col].unique()}
    col_dict[col] = anno_simple(anno[col],
                              legend_kws=dict(frameon=False),
                              colors=colors)
    
col_dict['Cell complexity correlation']= anno_scatterplot(
    anno['Cell_complexity_cor'],height=14,legend=False,grid=False
)

col_ha = HeatmapAnnotation(**col_dict,verbose=0,axis=1)
row_ha = HeatmapAnnotation(
    MetaProgram = anno_simple(anno['MetaProgram'],legend=False),verbose=0,axis=0
)
## plot
plt.rcParams['font.family'] = 'serif'
plt.figure(figsize=(10, 8),dpi=150)


cm = ClusterMapPlotter(data=sm.loc[order,order],
                       top_annotation=col_ha,
                       row_cluster=False,col_cluster=False,
#                        left_annotation=row_ha,
#                        col_split=rph_anno['RPH'],row_split=rph_anno['RPH'],
#                        row_split_gap=0.8,col_split_gap=0.8,
                       vmin=0,
                       vmax=25,
                       label='Similarity\n(Jaccard Index)', row_dendrogram=False,legend_gap=7,
                       cmap='Reds',rasterized=True)

## Change the ylim for the correlation plot
cutoff=.4
ax=col_ha.annotations[3].ax
ax.set_yticks([-0.8,-0.5,0,0.5,0.8]);
ax.axhline(y=cutoff,ls='--',color='gray')
ax.axhline(y=-cutoff,ls='--',color='gray')
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 28.22361111111111 mm
# Incresing ncol

# %% [markdown]
# ## Write out the Genesets for every MP

# %%
mp_gmt_path = f'{RESULT_TABLE}/MPs/{Celltype}/MP_Programs.gmt'
with open(mp_gmt_path,'w') as f:
    for mp in New_MP_Genesets:
        f.write('\t'.join([mp,'MetaProgram_HRpos']+MP_Genesets[mp].tolist())+'\n')

# %% [markdown]
# # Annotation of reccurent program

# %% [markdown]
# ## Gavish et al. 2023 - Hallmarks of transcriptional intratumour heterogeneity across a thousand tumours

# %%
ref_ITH = pd.read_excel(f'{EXTERNAL_DATA}/meta_programs_2023-07-13.xlsx',sheet_name='Fibroblasts')
ref_ITH = ref_ITH.loc[:,ref_ITH.columns!='Unassigned']

# %% [markdown]
# ### Similarity of individual RHP with reference ITH

# %%
n_top = min(ref_ITH.shape[0],robustRPH.shape[0])
rph_ref_sm = robustRPH.apply(
        lambda c1:
           ref_ITH.apply(
            lambda c2: jaccard_index(c1,c2) * 100
            ,axis=0)
        ,axis=0)

# %%
plt.rcParams['font.family'] = 'serif'
plt.figure(figsize=(10, 10))
cm = ClusterMapPlotter(data=rph_ref_sm.loc[:,order],
                       top_annotation=col_ha,
                       left_annotation=None,
                       show_rownames=True,
                       row_names_side='left',
                       row_cluster=False,col_cluster=False,
                       vmin=1,
                       vmax=25,
                       label='Similarity\n(Jaccard Index)', row_dendrogram=False,legend_gap=7,
                       cmap='OrRd',rasterized=True)
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 28.22361111111111 mm

# %% [markdown]
# ### Similarity of metaRHP with reference ITH

# %%
(New_MP_Genesets.apply(
        lambda c1:
           ref_ITH.apply(
            lambda c2: len(set(c1).intersection(set(c2)))
            ,axis=0)
        ,axis=0).max().sort_values() > 5)
# Out:
# MP9     False
# MP7     False
# MP8     False
# MP2      True
# MP4      True
# MP10     True
# MP3      True
# MP6      True
# MP5      True
# dtype: bool

# %%
meta_ref_sm = New_MP_Genesets.apply(
        lambda c1:
           ref_ITH.apply(
            lambda c2: len(set(c1).intersection(set(c2)))
            ,axis=0)
        ,axis=0)
meta_ref_sm = meta_ref_sm.loc[((meta_ref_sm >= 10).sum(axis=1)>=1),((meta_ref_sm >= 10).sum(axis=0)>=1)]
sns.heatmap(meta_ref_sm,lw=.2,
              cmap='Reds',vmin=5,vmax=25,square=True,cbar_kws={'label':'Intersection'})
# Out:
# <Axes: >

# %% [markdown]
# ## Hallmark and GO term bp/cc Geneset Enricher

# %%
import gseapy as gp
MP_pathway = {}
for program in New_MP_Genesets:
    genelist = New_MP_Genesets[program].tolist()
    get = True
    while get:
        try:
            enr = gp.enrichr(gene_list=genelist,
                     gene_sets=[f"{EXTERNAL_DATA}/KEGG_2021_Human.gmt",
                                f"{EXTERNAL_DATA}/h.all.v2023.1.Hs.symbols.gmt",
                                f"{EXTERNAL_DATA}/c5.go.bp.v2023.1.Hs.symbols.gmt",
                               f"{EXTERNAL_DATA}/c5.go.cc.v2023.1.Hs.symbols.gmt",
                               f"{EXTERNAL_DATA}/c5.go.mf.v2023.1.Hs.symbols.gmt"],
                     organism='human',
                     background=bg_genes.tolist(),
                     outdir=None, # don't write to disk
                            )
            get = False
        except Exception as e:
            if e!='Error sending gene list, try again later':
                print(e)
    res = enr.results
#     res = res.loc[res['Adjusted P-value']<0.05,:]
    MP_pathway[program] = res


top_n = 10
enr_res = {}
with pd.ExcelWriter(f'{RESULT_TABLE}/MPs/{Celltype}/ITH_Enricher.xlsx') as file:
    for name,temp in MP_pathway.items():
        top_geneset = []
        for geneset,df in temp.groupby('Gene_set'):
            top_geneset.append(
                df.sort_values(['Adjusted P-value'],
                                ascending=True).head(top_n)
            )
        result = pd.concat(top_geneset,axis=0)
        result.to_excel(file, sheet_name = name, index=False)
        enr_res[name] = result
del temp,result

# %%
enr_res = pd.read_excel(f'{RESULT_TABLE}/MPs/{Celltype}/ITH_Enricher.xlsx', sheet_name=None)

# %% [markdown]
# ## Manual annotation
#
# we recorded evidences for the program annotaion in the suppl slides.

# %%
enr_res['MP8']
# Out:
#                            Gene_set  \
# 0               KEGG_2021_Human.gmt
# 1               KEGG_2021_Human.gmt
# 2               KEGG_2021_Human.gmt
# 3               KEGG_2021_Human.gmt
# 4               KEGG_2021_Human.gmt
# 5               KEGG_2021_Human.gmt
# 6               KEGG_2021_Human.gmt
# 7               KEGG_2021_Human.gmt
# 8               KEGG_2021_Human.gmt
# 9               KEGG_2021_Human.gmt
# 10  c5.go.bp.v2023.1.Hs.symbols.gmt
# 11  c5.go.bp.v2023.1.Hs.symbols.gmt
# 12  c5.go.bp.v2023.1.Hs.symbols.gmt
# 13  c5.go.bp.v2023.1.Hs.symbols.gmt
# 14  c5.go.bp.v2023.1.Hs.symbols.gmt
# 15  c5.go.bp.v2023.1.Hs.symbols.gmt
# 16  c5.go.bp.v2023.1.Hs.symbols.gmt
# 17  c5.go.bp.v2023.1.Hs.symbols.gmt
# 18  c5.go.bp.v2023.1.Hs.symbols.gmt
# 19  c5.go.bp.v2023.1.Hs.symbols.gmt
# 20  c5.go.cc.v2023.1.Hs.symbols.gmt
# 21  c5.go.cc.v2023.1.Hs.symbols.gmt
# 22  c5.go.cc.v2023.1.Hs.symbols.gmt
# 23  c5.go.cc.v2023.1.Hs.symbols.gmt
# 24  c5.go.cc.v2023.1.Hs.symbols.gmt
# 25  c5.go.cc.v2023.1.Hs.symbols.gmt
# 26  c5.go.cc.v2023.1.Hs.symbols.gmt
# 27  c5.go.cc.v2023.1.Hs.symbols.gmt
# 28  c5.go.cc.v2023.1.Hs.symbols.gmt
# 29  c5.go.cc.v2023.1.Hs.symbols.gmt
# 30  c5.go.mf.v2023.1.Hs.symbols.gmt
# 31  c5.go.mf.v2023.1.Hs.symbols.gmt
# 32  c5.go.mf.v2023.1.Hs.symbols.gmt
# 33  c5.go.mf.v2023.1.Hs.symbols.gmt
# 34  c5.go.mf.v2023.1.Hs.symbols.gmt
# 35  c5.go.mf.v2023.1.Hs.symbols.gmt
# 36  c5.go.mf.v2023.1.Hs.symbols.gmt
# 37  c5.go.mf.v2023.1.Hs.symbols.gmt
# 38  c5.go.mf.v2023.1.Hs.symbols.gmt
# 39  c5.go.mf.v2023.1.Hs.symbols.gmt
# 40     h.all.v2023.1.Hs.symbols.gmt
# 41     h.all.v2023.1.Hs.symbols.gmt
# 42     h.all.v2023.1.Hs.symbols.gmt
# 43     h.all.v2023.1.Hs.symbols.gmt
# 44     h.all.v2023.1.Hs.symbols.gmt
# 45     h.all.v2023.1.Hs.symbols.gmt
# 46     h.all.v2023.1.Hs.symbols.gmt
# 47     h.all.v2023.1.Hs.symbols.gmt
# 48     h.all.v2023.1.Hs.symbols.gmt
# 49     h.all.v2023.1.Hs.symbols.gmt
#
#                                                  Term Overlap   P-value  \
# 0                                   Viral myocarditis    2/39  0.011875
# 1                         Hypertrophic cardiomyopathy    2/50  0.019059
# 2     Arrhythmogenic right ventricular cardiomyopathy    2/49  0.018345
# 3                              Dilated cardiomyopathy    2/57  0.024368
# 4                            ECM-receptor interaction    2/60  0.026808
# 5             Transcriptional misregulation in cancer   3/114  0.012494
# 6                                  Pathways in cancer   4/363  0.067788
# 7                          Osteoclast differentiation    1/82  0.295730
# 8                          PI3K-Akt signaling pathway   2/225  0.248076
# 9                                   Pancreatic cancer    1/62  0.232684
# 10                                 GOBP_CELL_ADHESION  13/873  0.000051
# 11  GOBP_EXTERNAL_ENCAPSULATING_STRUCTURE_ORGANIZA...   7/216  0.000033
# 12                GOBP_BASEMENT_MEMBRANE_ORGANIZATION    3/30  0.000271
# 13  GOBP_NEGATIVE_REGULATION_OF_FAT_CELL_DIFFERENT...    3/35  0.000430
# 14              GOBP_EXTRACELLULAR_MATRIX_DISASSEMBLY    3/38  0.000549
# 15                                   GOBP_ENDOCYTOSIS   7/380  0.001048
# 16  GOBP_HOMOPHILIC_CELL_ADHESION_VIA_PLASMA_MEMBR...    3/59  0.001989
# 17                              GOBP_TUBE_DEVELOPMENT   9/695  0.002353
# 18                            GOBP_TUBE_MORPHOGENESIS   8/565  0.002432
# 19                GOBP_NEPHRON_EPITHELIUM_DEVELOPMENT    3/68  0.002985
# 20              GOCC_EXTERNAL_ENCAPSULATING_STRUCTURE   8/335  0.000075
# 21                          GOCC_AP_2_ADAPTOR_COMPLEX     2/8  0.000488
# 22                             GOCC_ADHERENS_JUNCTION   4/135  0.002542
# 23                            GOCC_ANCHORING_JUNCTION   9/648  0.001453
# 24                        GOCC_PLATELET_ALPHA_GRANULE    3/60  0.002087
# 25      GOCC_COLLAGEN_CONTAINING_EXTRACELLULAR_MATRIX   6/271  0.000961
# 26             GOCC_CLATHRIN_COATED_ENDOCYTIC_VESICLE    3/54  0.001540
# 27                             GOCC_BASEMENT_MEMBRANE    3/62  0.002293
# 28                   GOCC_CLATHRIN_COAT_OF_COATED_PIT    2/15  0.001796
# 29               GOCC_PLATELET_ALPHA_GRANULE_MEMBRANE    2/13  0.001341
# 30   GOMF_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT   4/114  0.001368
# 31                 GOMF_METALLOENDOPEPTIDASE_ACTIVITY    3/79  0.004558
# 32                     GOMF_SERINE_HYDROLASE_ACTIVITY    3/82  0.005059
# 33                  GOMF_STRUCTURAL_MOLECULE_ACTIVITY   5/437  0.037280
# 34                      GOMF_GDP_PHOSPHATASE_ACTIVITY     1/6  0.025246
# 35                      GOMF_COA_TRANSFERASE_ACTIVITY     1/4  0.016901
# 36  GOMF_MECHANOSENSITIVE_MONOATOMIC_ION_CHANNEL_A...     1/6  0.025246
# 37  GOMF_CORECEPTOR_ACTIVITY_INVOLVED_IN_WNT_SIGNA...     1/9  0.037634
# 38  GOMF_CORECEPTOR_ACTIVITY_INVOLVED_IN_WNT_SIGNA...     1/6  0.025246
# 39                  GOMF_CYTOSKELETAL_PROTEIN_BINDING   7/642  0.018088
# 40         HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   7/184  0.000012
# 41                                HALLMARK_MYOGENESIS   4/123  0.001810
# 42                               HALLMARK_COAGULATION    2/82  0.047428
# 43                              HALLMARK_ANGIOGENESIS    1/23  0.093432
# 44                           HALLMARK_APICAL_JUNCTION   1/134  0.436846
# 45                   HALLMARK_CHOLESTEROL_HOMEOSTASIS    1/53  0.202539
# 46                                HALLMARK_DNA_REPAIR   1/124  0.412056
# 47                   HALLMARK_ESTROGEN_RESPONSE_EARLY   1/154  0.483393
# 48                       HALLMARK_IL2_STAT5_SIGNALING   1/142  0.455938
# 49                     HALLMARK_INFLAMMATORY_RESPONSE   1/112  0.380893
#
#     Adjusted P-value  Odds Ratio  Combined Score  \
# 0           0.165318   16.046048       71.137170
# 1           0.165318   12.395047       49.087354
# 2           0.165318   12.657081       50.607724
# 3           0.165318   10.825207       40.210007
# 4           0.165318   10.267424       37.158276
# 5           0.165318    7.665471       33.593861
# 6           0.358310    3.055723        8.224065
# 7           0.377311    4.324038        5.268005
# 8           0.377311    2.649392        3.693310
# 9           0.377311    5.740084        8.369470
# 10          0.021808    4.539431       44.865248
# 11          0.021808    9.465476       97.767417
# 12          0.077182   31.305072      257.142107
# 13          0.091932   26.477571      205.241102
# 14          0.093949   24.233803      181.915134
# 15          0.149376    5.233578       35.905651
# 16          0.231083   15.199162       94.543776
# 17          0.231083    3.676155       22.247611
# 18          0.231083    4.001256       24.082980
# 19          0.255179   13.100603       76.170900
# 20          0.011755    6.951756       65.995532
# 21          0.038067   92.819191      707.758008
# 22          0.039652    8.521648       50.915871
# 23          0.039652    3.963158       25.896419
# 24          0.039652   14.933547       92.170069
# 25          0.039652    6.296854       43.745165
# 26          0.039652   16.681962      108.031327
# 27          0.039652   14.429102       87.699282
# 28          0.039652   44.663994      282.383585
# 29          0.039652   52.440610      346.853592
# 30          0.198394   10.159539       66.994352
# 31          0.244519   11.206261       60.411892
# 32          0.244519   10.780602       56.992555
# 33          0.263070    3.152220       10.368566
# 34          0.263070   64.493113      237.276084
# 35          0.263070  101.363636      413.603665
# 36          0.263070   64.493113      237.276084
# 37          0.263070   41.720143      136.836215
# 38          0.263070   64.493113      237.276084
# 39          0.263070    3.004829       12.056853
# 40          0.000174   11.203011      127.327943
# 41          0.013576    9.387097       59.273503
# 42          0.237142    7.447333       22.703454
# 43          0.350371   15.742088       37.316904
# 44          0.485619    2.627965        2.176412
# 45          0.485619    6.729293       10.745488
# 46          0.485619    2.843209        2.520779
# 47          0.485619    2.281611        1.658560
# 48          0.485619    2.477674        1.945959
# 49          0.485619    3.152466        3.042877
#
#                                                 Genes
# 0                                          SGCD;LAMA2
# 1                                          LAMA2;SGCD
# 2                                          LAMA2;SGCD
# 3                                          LAMA2;SGCD
# 4                                         THBS2;LAMA2
# 5                                  MITF;RUNX2;RUNX1T1
# 6                             MITF;RALA;RUNX1T1;LAMA2
# 7                                                MITF
# 8                                         THBS2;LAMA2
# 9                                                RALA
# 10  NEGR1;FAP;SDK1;POSTN;LAMA2;HMCN1;ADAM12;FRMD5;...
# 11         FAP;POSTN;LAMA2;HMCN1;MMP11;MYO1E;SH3PXD2B
# 12                                  MMP11;HMCN1;LAMA2
# 13                                MMP11;WWTR1;RUNX1T1
# 14                                 MMP11;FAP;SH3PXD2B
# 15           RALA;GULP1;BICD1;STON2;MYO1E;SPON2;SGIP1
# 16                                   HMCN1;SDK1;PCDH7
# 17  FAP;RALA;ADAM12;WWTR1;ARHGAP24;KIF26B;THBS2;MY...
# 18   FAP;RALA;ADAM12;ARHGAP24;KIF26B;THBS2;MYO1E;SGCD
# 19                                 KIF26B;WWTR1;MYO1E
# 20     POSTN;LAMA2;HMCN1;THBS2;MMP11;GPC6;SPON2;HTRA1
# 21                                        STON2;SGIP1
# 22                         ARHGAP24;HMCN1;MYO1E;FRMD5
# 23  FAP;RALA;HMCN1;ARHGAP24;KAZN;KCND2;MYO1E;FRMD5...
# 24                                 THBS2;PCDH7;LHFPL2
# 25                 POSTN;LAMA2;HMCN1;THBS2;GPC6;HTRA1
# 26                                  STON2;MYO1E;SGIP1
# 27                                  HMCN1;THBS2;LAMA2
# 28                                        STON2;SGIP1
# 29                                       PCDH7;LHFPL2
# 30                            HMCN1;THBS2;POSTN;LAMA2
# 31                                 MMP11;ADAM12;HTRA1
# 32                                    MMP11;FAP;HTRA1
# 33                      POSTN;LAMA2;HMCN1;BICD1;THBS2
# 34                                             ENTPD1
# 35                                              SUGCT
# 36                                             PIEZO2
# 37                                               GPC6
# 38                                               GPC6
# 39           SHTN1;MTCL1;RALA;BICD1;MYO1E;FRMD5;SGIP1
# 40            FAP;POSTN;LAMA2;ADAM12;THBS2;HTRA1;SGCD
# 41                            WWTR1;ADAM12;LAMA2;SGCD
# 42                                        MMP11;HTRA1
# 43                                              POSTN
# 44                                              NEGR1
# 45                                             NIBAN1
# 46                                               RALA
# 47                                               KAZN
# 48                                              MYO1E
# 49                                              PCDH7

# %%
New_MP_Genesets.apply(
        lambda c1:
           ref_ITH.apply(
            lambda c2: len(set(c1).intersection(set(c2)))
            ,axis=0)
        ,axis=0).idxmax().to_dict()
# Out:
# {'MP5': 'Interferon',
#  'MP7': 'MHC-II/Cytokine',
#  'MP3': 'CAF1',
#  'MP4': 'CAF1',
#  'MP2': 'Complement',
#  'MP6': 'Pericyte-like',
#  'MP10': 'Stress',
#  'MP8': 'CAF1',
#  'MP9': 'CAF2'}

# %% [markdown]
# ## Final MP annotation

# %%
MP_anno_map = {

 'MP5': 'Interferon',
 'MP7': 'MHCII',
 'MP3': 'Coagulation',
 'MP4': 'Myo-TGFB',
 'MP2': 'Lipid',
 'MP6': 'Pericyte-like',
 'MP10': 'Stress',
 'MP8': 'Myogenesis',
 'MP9': 'Fibrosis'
    

}

# %% [markdown]
# ## Assign the annotation to MPs column

# %%
anno['MPs'] = anno.MetaProgram.map(MP_anno_map)
anno['MPs'].value_counts().sort_index()
# Out:
# Coagulation      45
# Fibrosis          8
# Interferon       15
# Lipid            47
# MHCII             8
# Myo-TGFB         16
# Myogenesis       12
# Pericyte-like    12
# Stress            8
# Name: MPs, dtype: int64

# %%
MP_Visual_Genes = {
 'MP5': ['JAK2','STAT1','CXCL10'],
 'MP7': ['CD74','HLA-DRA','TOX'],
 'MP3': ['COL11A1','FN1','THBS1'],
 'MP4': ['MYLK','SEMA3C','TGFBR2'],
 'MP2': ['ABCA6','ABCA10','ABCA8'],
 'MP6': ['GUCY1A1','GUCY1A2','EDNRA'],
 'MP10': ['CCNL1','NR4A1','SERPINE1'],
 'MP8': ['ADAM12','SGCD','WWTR1'],
 'MP9':['PDE10A','PDE5A','PDE7B'],
}

# %%
for k,v in MP_Visual_Genes.items():
    for vx in v:
        _total = (New_MP_Genesets==vx).sum().sum()
        if _total > 1:
            print(k,vx)

# %%
genes = pd.Series(np.vstack(MP_Visual_Genes.values()).flatten())
genes.index=genes
dt = New_MP_Genesets.apply(lambda c: genes.map(lambda x: x in c.values),axis=0).astype(int)
dt = dt.sort_values(dt.columns.tolist())

df_rows = pd.DataFrame(MP_Visual_Genes).unstack().reset_index().set_index(0)
colors = { MP_anno_map[k]:v for k,v in COLOR_PAlETTE['MetaProgram'].items() if k in df_rows['level_0'].unique()}
df_rows['MP'] = df_rows['level_0'].map(MP_anno_map)
df_rows = df_rows.sort_values('level_0')
col_orders = df_rows['level_0'].unique().tolist()
dt = dt[col_orders].sort_values(col_orders,ascending=False)
df_rows = df_rows.loc[dt.index,:]

row_ha = HeatmapAnnotation(
    Function=anno_simple(df_rows['MP'],legend=False,
                           legend_kws=dict(frameon=False),
                           colors=colors),
     Anno=anno_label(df_rows['MP'],legend=False,
                          colors=colors,merge=True),
    verbose=0,axis=0,plot_legend=True)


plt.figure(figsize=(3, 6),dpi=150)
cm = ClusterMapPlotter(data=dt,
                       right_annotation=row_ha,
                       col_cluster=False,
                       row_cluster=False,
                       show_colnames=True,
                       show_rownames=True,
                       vmax=1,
                       vmin=0,
                       label='Gene In the MP',
                       cmap='Greys',rasterized=True,col_names_side='top')
# plt.suptitle('Metaprogram related function')
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 7.5 mm

# %% [markdown]
# ## Store the annotation

# %%
mp_anno_path = f'{RESULT_TABLE}/MPs/{Celltype}/MetaProgram_Annotation.csv'
anno.to_csv(mp_anno_path,index=True)

# %% [markdown]
# # Cellstate annotation

# %%
scores_path = f'{RESULT_TABLE}/MPs/{Celltype}/signature_scores.csv'
sc.pp.normalize_total(adata, target_sum=1e4)
mp_result = sp.ext.VISION(data=adata,gmt_files=[mp_gmt_path],outdir='.')

mp_result.to_csv(scores_path)
ref_ITH=pd.read_table(mp_gmt_path,header=None,index_col=0).drop([1],axis=1).T
ref_anno = pd.read_csv(mp_anno_path)
MP_anno_map = ref_anno[['MetaProgram','MPs']].drop_duplicates().set_index('MetaProgram')['MPs'].to_dict()
# get MP sores on all cells 
scores = pd.read_csv(scores_path,index_col=0)
# select the signature scoring method
scores.columns = scores.columns.map(lambda x:x.split('_')[0]).map(MP_anno_map)
scores
# Out:
# Rscript /home/analysis/scPipe/scPipe/Rscripts/VISION.R --gmt_files ..//data/table/MPs/CAF/MP_Programs.gmt --h5ad /tmp/tmp8ulgzn3e/count.h5ad --output_file /tmp/tmp8ulgzn3e/vision.tsv
# $gmt_files
# [1] "..//data/table/MPs/CAF/MP_Programs.gmt"
#
# $h5ad
# [1] "/tmp/tmp8ulgzn3e/count.h5ad"
#
# $output_file
# [1] "/tmp/tmp8ulgzn3e/vision.tsv"
# Loading data from ..//data/table/MPs/CAF/MP_Programs.gmt ...
#
# Using 23123/36601 genes detected in 0.10% of cells for signature analysis.
# See the `sig_gene_threshold` input to change this behavior.
#
# Evaluating signature scores on cells...
#
# 'as(<matrix>, "dgeMatrix")' is deprecated.
# Use 'as(as(as(., "dMatrix"), "generalMatrix"), "unpackedMatrix")' instead.
# See help("Deprecated") and help("Matrix-deprecated").
# Evaluating signature-gene importance...
#
# Warning messages:
# 1: In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 13.1 GiB
# 2: In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 13.1 GiB
#                                                     Interferon     MHCII  \
# TCTCAATTCAATCTAG-1_CCG1112_16_T4_A1_CCG1112_MO_...    1.070907  0.583225
# GGTCTTTGTAATAACC-1_CCG1112_16_T4_A1_CCG1112_MO_...    1.096463  0.754656
# CATTATCTCGTTCACC-1_CCG1112_16_T4_A1_CCG1112_MO_...    0.878099  0.832159
# AATATCCCAGGACCTT-1_CCG1112_16_T4_A1_CCG1112_MO_...    0.630541  0.703732
# TGAACAACACCTAATG-1_CCG1112_16_T4_A1_CCG1112_MO_...    1.326327  0.856126
# ...                                                        ...       ...
# TTTACTGGTATCAGTC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.645439 -0.100203
# CCAATCCGTTCGCTAA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.268572  0.083096
# TTCTCAAGTCTAGTCA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.262333  0.445288
# GTACTCCCACGAGAGT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.115331  0.115331
# GGCTGGTTCGAATGCT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...    0.330337  0.288126
#
#                                                     Coagulation  Myo-TGFB  \
# TCTCAATTCAATCTAG-1_CCG1112_16_T4_A1_CCG1112_MO_...     2.400826  2.691850
# GGTCTTTGTAATAACC-1_CCG1112_16_T4_A1_CCG1112_MO_...     1.870539  2.503927
# CATTATCTCGTTCACC-1_CCG1112_16_T4_A1_CCG1112_MO_...     2.770342  2.985388
# AATATCCCAGGACCTT-1_CCG1112_16_T4_A1_CCG1112_MO_...     2.212539  3.644899
# TGAACAACACCTAATG-1_CCG1112_16_T4_A1_CCG1112_MO_...     2.146068  2.628093
# ...                                                         ...       ...
# TTTACTGGTATCAGTC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...     1.396184  1.924475
# CCAATCCGTTCGCTAA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...     0.268572  0.803654
# TTCTCAAGTCTAGTCA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...     0.749258  0.485626
# GTACTCCCACGAGAGT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...     0.294639  1.646267
# GGCTGGTTCGAATGCT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...     0.799254  0.429434
#
#                                                        Lipid  Pericyte-like  \
# TCTCAATTCAATCTAG-1_CCG1112_16_T4_A1_CCG1112_MO_...  4.846743       1.137373
# GGTCTTTGTAATAACC-1_CCG1112_16_T4_A1_CCG1112_MO_...  5.662187       1.108763
# CATTATCTCGTTCACC-1_CCG1112_16_T4_A1_CCG1112_MO_...  4.082625       1.304351
# AATATCCCAGGACCTT-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.787448       1.358622
# TGAACAACACCTAATG-1_CCG1112_16_T4_A1_CCG1112_MO_...  5.486287       1.303490
# ...                                                      ...            ...
# TTTACTGGTATCAGTC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  1.142171       0.500332
# CCAATCCGTTCGCTAA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  2.377088      -0.102381
# TTCTCAAGTCTAGTCA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  1.687988      -0.103575
# GTACTCCCACGAGAGT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  1.320460       0.254106
# GGCTGGTTCGAATGCT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.739150       0.330337
#
#                                                       Stress  Myogenesis  \
# TCTCAATTCAATCTAG-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.008929    2.733005
# GGTCTTTGTAATAACC-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.382617    2.590241
# CATTATCTCGTTCACC-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.097817    3.330597
# AATATCCCAGGACCTT-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.797501    3.072633
# TGAACAACACCTAATG-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.179170    2.810503
# ...                                                      ...         ...
# TTTACTGGTATCAGTC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.645439    1.979202
# CCAATCCGTTCGCTAA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.391850    2.167350
# TTCTCAAGTCTAGTCA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.119718    1.257782
# GTACTCCCACGAGAGT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.498054    2.397550
# GGCTGGTTCGAATGCT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.163533    0.799254
#
#                                                     Fibrosis
# TCTCAATTCAATCTAG-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.731122
# GGTCTTTGTAATAACC-1_CCG1112_16_T4_A1_CCG1112_MO_...  2.034055
# CATTATCTCGTTCACC-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.200788
# AATATCCCAGGACCTT-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.071550
# TGAACAACACCTAATG-1_CCG1112_16_T4_A1_CCG1112_MO_...  1.563090
# ...                                                      ...
# TTTACTGGTATCAGTC-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.338460
# CCAATCCGTTCGCTAA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.680376
# TTCTCAAGTCTAGTCA-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.343011
# GTACTCCCACGAGAGT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.612721
# GGCTGGTTCGAATGCT-1_CCG1112_13_T3_A1_SN_5GEX_CCG...  0.840717
#
# [47964 rows x 9 columns]

# %%
from signaturescoring.scoring_methods.gmm_postprocessing import GMMPostprocessor
import anndata
macs = anndata.AnnData(obs=scores)
# initialize GMMPostprocessor
gmm_post = GMMPostprocessor(
    n_components=scores.shape[1]
)
# fit the GMM model on the 3 columns of the scores
features_name = scores.columns.tolist()
store_name_pred, store_names_proba, _ = gmm_post.fit_and_predict(macs,features_name )

# assign clusters to signatures
assignments = gmm_post.assign_clusters_to_signatures(macs,features_name, store_names_proba, plot=False)
scoring_names_gmm = []
for key, val in assignments.items():
    if key =='rest':
        continue
    macs.obs[key+'_gmm'] = macs.obs[val].copy()
    scoring_names_gmm.append(key+'_gmm')

# %%
assignments
# Out:
# {'Interferon': '1_GMM_proba',
#  'MHCII': '3_GMM_proba',
#  'Coagulation': '6_GMM_proba',
#  'Myo-TGFB': '4_GMM_proba',
#  'Lipid': '5_GMM_proba',
#  'Pericyte-like': '8_GMM_proba',
#  'Stress': '4_GMM_proba',
#  'Myogenesis': '2_GMM_proba',
#  'Fibrosis': '0_GMM_proba',
#  'rest': {'7_GMM_proba'}}

# %%
curr_val= macs.obs[scoring_names_gmm].idxmax(axis="columns")
cellstate= curr_val.map(lambda x:f'{Celltype}.'+x.split('_')[0]).rename('Cellstate').to_frame()
cellstate.to_csv(f'{RESULT_TABLE}/MPs/{Celltype}/Annotation.csv')

# %%
# cross sanity check
obs = pd.read_csv(f'{RESULT_TABLE}/GEX_OBS.csv',index_col=0)
adata.obs['Cellstate'] = obs.loc[adata.obs.index,'Cellstate']
pd.crosstab(adata.obs.loc[cellstate.index,'Cellstate'],cellstate['Cellstate'])
# Out:
# Cellstate  CAF.Coagulation  CAF.Fibrosis  CAF.Interferon  CAF.Lipid  \
# Cellstate
# CAF                   8489          6457            2935       7914
#
# Cellstate  CAF.MHCII  CAF.Myo-TGFB  CAF.Myogenesis  CAF.Pericyte-like
# Cellstate
# CAF             3076          7569            5840               5684

# %%
adata.obs['Cellstate']= cellstate['Cellstate']

# %% [markdown]
# ## Marker visualization

# %%
sp.utils.log1pNorm(adata)
adata.obs = adata.obs.merge(sample_meta,left_on='Sample',right_on='CCG_ID')

# %%
ref_ITH=pd.read_table(mp_gmt_path,header=None,index_col=0).drop([1],axis=1).T
anno = pd.read_csv(mp_anno_path,index_col=0)
MP_anno_map = anno[['MetaProgram','MPs']].drop_duplicates().set_index('MetaProgram')['MPs'].to_dict()
MP_anno_map_reverse = {v:k for k,v in MP_anno_map.items()}
MP_anno_map = anno[['MetaProgram','MPs']].drop_duplicates().set_index('MetaProgram').apply(lambda r:f"{r['MPs']}({r.name})",axis=1).to_dict()
ref_ITH.columns = ref_ITH.columns.map(MP_anno_map)
ref_ITH=ref_ITH.melt()
ref_ITH.columns = ['Program','gene']
ref_ITH = ref_ITH.drop_duplicates(subset=['gene'],keep=False).set_index('gene')

# %%
col_split_order =

# %%
mp_map_df = pd.Series(MP_anno_map_reverse,name='MP').to_frame()
mp_map_df.index.name = 'anno'
mp_map_df.reset_index(inplace=True)
mp_map_df['order']= mp_map_df['MP'].map(lambda x: int(x.replace('MP','')))
mp_map_df = mp_map_df.sort_values('order')
mp_map_df['MP_anno'] = mp_map_df['MP'].map(lambda x: f'{MP_anno_map[x]}')
mp_map_df
# Out:
#             anno    MP  order             MP_anno
# 4          Lipid   MP2      2          Lipid(MP2)
# 2    Coagulation   MP3      3    Coagulation(MP3)
# 3       Myo-TGFB   MP4      4       Myo-TGFB(MP4)
# 0     Interferon   MP5      5     Interferon(MP5)
# 5  Pericyte-like   MP6      6  Pericyte-like(MP6)
# 1          MHCII   MP7      7          MHCII(MP7)
# 7     Myogenesis   MP8      8     Myogenesis(MP8)
# 8       Fibrosis   MP9      9       Fibrosis(MP9)
# 6         Stress  MP10     10        Stress(MP10)

# %%
palette={}
palette['Program'] = {k.replace(f'{Celltype}.','')+f"({MP_anno_map_reverse[k.replace(f'{Celltype}.','')]})":v for k,v in COLOR_PAlETTE['Cellstate'].items() if Celltype in k}
for c in ['BestResponse','Patient','Timepoint','Cellstate']:
    palette[c] = COLOR_PAlETTE[c]
aggregate_heatmap(adata=adata,
                  features=ref_ITH,
                  top_anno_columns=['Cellstate','BestResponse','Patient','Timepoint'],
                  col_split='Cellstate',
                  col_split_gap=1,
                  col_split_order = [ f"{Celltype}.{x}" for x in mp_map_df['anno'].tolist() if f"{Celltype}.{x}" in adata.obs.Cellstate.unique()],
                  row_split='Program',
                  row_split_gap=1,
                  row_split_order=mp_map_df['MP_anno'].tolist(),
                  palette=palette,
                  figsize=(10,10),
                  vmin=-3,
                  vmax=3,
                  standard_normalization=True,
                  cbar_label='Expression\n(Normalized)',
                  cmap='RdBu_r'
                 )
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Collecting legends..
# Plotting legends..
# Estimated legend width: 78.67083333333333 mm
